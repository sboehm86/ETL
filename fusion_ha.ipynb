# %%
import pandas as pd

# %%
us_path='../ETL/clean_us2.csv'
fr_path='../ETL/clean_fr2.csv'

# %%
us_df2=pd.read_csv(us_path)
fr_df2=pd.read_csv(fr_path)

# %%
us_gr=us_df2.groupby(['category_id'])
#us_gr.head(5)

# %%
fr_gr=fr_df2.groupby(['category_id'])
fr_gr.head()
# Out:
#        Unnamed: 0 trending_date  \
# 0               0      17.14.11
# 1               1      17.14.11
# 2               2      17.14.11
# 3               3      17.14.11
# 4               4      17.14.11
# ...           ...           ...
# 31405       31405      18.28.04
# 31653       31653      18.29.04
# 31836       31836      18.30.04
# 34305       34305      18.13.05
# 34484       34484      18.14.05
#
#                                                    title  category_id  \
# 0               Malika LePen : Femme de Gauche - Trailer           24
# 1      LA PIRE PARTIE ft Le Rire Jaune, Pierre Croce,...           24
# 2      DESSINS ANIMEÌS FRANCÌ§AIS VS RUSSES 2 - Dani...           23
# 3                        PAPY GRENIER - METAL GEAR SOLID           20
# 4      QUI SAUTERA LE PLUS HAUT ? (VÃ‰LO SKATE ROLLER...           17
# ...                                                  ...          ...
# 31405       Cerberus - Film COMPLET gratuit en franÃ§ais           30
# ...
